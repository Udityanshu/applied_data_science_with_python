# %% [markdown]
# # Box plots

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.009178      0.501855      2.001891
# std        1.009963      0.289324      1.418318
# min       -4.245285      0.000186      0.008832
# 25%       -0.705171      0.255229      0.956744
# 50%       -0.007927      0.503219      1.677587
# 75%        0.674521      0.751827      2.682449
# max        4.312776      0.999978     11.542422

# %% [markdown]
# create a `boxplot` of the normal data, assign the output to a variable to supress output

# %%
plt.figure()
_ = plt.boxplot(df['normal'], whis=[0,100]) # set whis=[0,100], instead of using whis='range'
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# clear the current figure using `clf`
#  plot boxplots for all three of df's columns

# %%
plt.clf()
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis=[0,100])

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il
plt.figure()
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis=[0,100])
# overlay axis on top of another 
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# switch the yaxis ticks for ax2 to the right side

# %%
ax2.yaxis.tick_right()

# %%
plt.figure()
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ])
# Out:
# <img src="data:image/png;base64,..." width="640">
