# %% [markdown]
# # Subplots

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# subplot with 1 row, 2 columns and current axis is 1st subplot axes

# %%
plt.figure()
plt.subplot(1,2,1)
linear_data = np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# subplot with 1 row, 2 columns and current axis is 2nd subplot axes

# %%
exponential_data = linear_data**2
plt.subplot(1, 2, 2)
plt.plot(exponential_data, '-x')

# %% [markdown]
# plot exponential data on 1st subplot axes

# %%
plt.subplot(1, 2, 1)
plt.plot(exponential_data, '-x')
# Out:
# C:\Users\udity\OneDrive\Documents\Python\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# pass `sharey=ax1` to ensure the two subplots share the same y-axis

# %%
plt.figure()
ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# the right hand side is equivalent to left hand side

# %%
plt.figure()
plt.subplot(1, 2, 1) == plt.subplot(121)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\udity\OneDrive\Documents\Python\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# True

# %% [markdown]
# create 3x3 of subplots

# %%
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9)) = plt.subplots(3, 3, sharex=True, sharey=True)
# plot the linear data on the 5th subplot axes
ax5.plot(linear_data, '-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    for labels in ax.get_xticklabels() + ax.get_yticklabels():
        labels.set_visible(True)

# %%
# necessary on some systems to update the plot
plt.gcf().canvas.draw()
